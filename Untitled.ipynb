# %%
import numpy as np 
for i in [500, 1000, 2000, 5000, 10000]:
    ee_net = np.load("./results/eenet_results1 step_size {}.npy".format(i))
    ee_net_m = np.mean(ee_net, axis = 0)
    print(ee_net)

# %%
! python EENet_runcopy.py
# Out:
# /home/yikunb2/anaconda3/lib/python3.8/site-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448278899/work/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# f1_lr 0.01
# Gradient Aggregation Dimenstion: 15685
# f2_lr, hidden 0.001 608
# f3_lr 0.001
# [0.15622202] [-0.93792385]
# round:0, regret: 1.0,  average_regret: 1.000, loss_1:0.0005, loss_2:0.0009, loss_3:0.0000
# round:50, regret: 39.0,  average_regret: 0.765, loss_1:0.0008, loss_2:0.0099, loss_3:0.0000
# [0.74740839] [0.28783798]
# ...

# %%
import numpy as np
ee_net = np.load("./results/eenetcopy_results2 step_size 50.npy")

print(ee_net)
# Out:
# [[1.000e+00 2.000e+00 2.000e+00 ... 1.042e+03 1.042e+03 1.042e+03]
#  [1.000e+00 2.000e+00 3.000e+00 ... 1.010e+03 1.010e+03 1.010e+03]
#  [1.000e+00 2.000e+00 3.000e+00 ... 1.028e+03 1.028e+03 1.028e+03]]

# %%
t  = 1
c = (1/np.log(t+50)) + 1.0
print(c)
# Out:
# 1.2543347781440422
